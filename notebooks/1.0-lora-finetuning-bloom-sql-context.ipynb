# %%
# !pip install -q bitsandbytes datasets accelerate loralib
# !pip install -q git+https://github.com/huggingface/peft.git git+https://github.com/huggingface/transformers.git

# %%
import torch
import torch.nn as nn
import bitsandbytes as bnb
from transformers import AutoTokenizer, AutoConfig, AutoModelForCausalLM
import os

# %% [markdown]
# # Load Model

# %%
MODEL_ID = 'bigscience/bloom-1b1'
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float32,
    device_map='auto',
)

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

# %%
print(model)
# Out:
# BloomForCausalLM(
#   (transformer): BloomModel(
#     (word_embeddings): Embedding(250880, 1536)
#     (word_embeddings_layernorm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#     (h): ModuleList(
#       (0-23): 24 x BloomBlock(
#         (input_layernorm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#         (self_attention): BloomAttention(
#           (query_key_value): Linear(in_features=1536, out_features=4608, bias=True)
#           (dense): Linear(in_features=1536, out_features=1536, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (post_attention_layernorm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#         (mlp): BloomMLP(
#           (dense_h_to_4h): Linear(in_features=1536, out_features=6144, bias=True)
#           (gelu_impl): BloomGelu()
#           (dense_4h_to_h): Linear(in_features=6144, out_features=1536, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1536, out_features=250880, bias=False)
# )

# %% [markdown]
# # Freeze Parameters

# %%
for params in model.parameters():
  params.requires_grad = False # Freeze all parameter
  if params.ndim == 1:
    params.data = params.data.to(torch.float32) # cast to float32 for stability

# Enables the gradients for the input embeddings.
# This is useful for fine-tuning adapter weights while keeping the model weights fixed.
model.enable_input_require_grads()
# reduce number of stored activations
model.gradient_checkpointing_enable()

# %%
#Cast the last layer for the ouput of the LM to be float of fp32
class CastToFloat(nn.Sequential):
    def forward(self,x):
        return super().forward(x).to(torch.float32)
model.lm_head = CastToFloat(model.lm_head)

# %% [markdown]
# # Lora Configuration

# %%
print(model)
# Out:
# BloomForCausalLM(
#   (transformer): BloomModel(
#     (word_embeddings): Embedding(250880, 1536)
#     (word_embeddings_layernorm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#     (h): ModuleList(
#       (0-23): 24 x BloomBlock(
#         (input_layernorm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#         (self_attention): BloomAttention(
#           (query_key_value): Linear(in_features=1536, out_features=4608, bias=True)
#           (dense): Linear(in_features=1536, out_features=1536, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (post_attention_layernorm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#         (mlp): BloomMLP(
#           (dense_h_to_4h): Linear(in_features=1536, out_features=6144, bias=True)
#           (gelu_impl): BloomGelu()
#           (dense_4h_to_h): Linear(in_features=6144, out_features=1536, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): CastToFloat(
#     (0): Linear(in_features=1536, out_features=250880, bias=False)
#   )
# )

# %%
from peft import LoraConfig, get_peft_model
target_modules_to_apply = ['query_key_value', # as in the paper
                          'dense_h_to_4h',
                          'dense_4h_to_h']
task = 'CAUSAL_LM'
desired_rank = 8
lora_alpha = desired_rank*2
lora_dropout = 0.01
lora_config = LoraConfig(
    task_type = task,
    r = desired_rank,
    lora_alpha = lora_alpha,
    lora_dropout = lora_dropout,
    target_modules=target_modules_to_apply
)

peft_model = get_peft_model(model,lora_config)
peft_model.print_trainable_parameters()
# Out:
# trainable params: 4,128,768 || all params: 1,069,443,072 || trainable%: 0.38606711363127144

# %% [markdown]
# # Load Dataset

# %%
# pip install -U datasets

# %%
from datasets import load_dataset

dataset = load_dataset("b-mc2/sql-create-context")
# Out:
# Downloading readme:   0%|          | 0.00/4.43k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.8M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'answer', 'context'],
#         num_rows: 78577
#     })
# })

# %%
from torch.utils.data import random_split

generator1 = torch.Generator().manual_seed(42)
train,val,test = random_split(dataset['train'], [0.6,0.2,0.2], generator=generator1)

# %%
print(f'Sizes:\ntrain-> {len(train)}\nval-> {len(val)}\ntest-> {len(test)}\n')
# Out:
# Sizes:
# train-> 47147
# val-> 15715
# test-> 15715

# %%
def slice_from_indices(indices):
  return dataset['train'][indices]

train_set = slice_from_indices(train.indices)
val_set   = slice_from_indices(val.indices)
test_set  = slice_from_indices(test.indices)

# %%
train_set.keys()
# Out:
# dict_keys(['question', 'answer', 'context'])

# %%
train_set['answer'][0]
# Out:
# 'SELECT MIN(points) FROM table_name_36 WHERE position > 5'

# %%
import pandas as pd
Train = pd.DataFrame(train_set)
Val   = pd.DataFrame(val_set)
Test = pd.DataFrame(test_set)

# %%
Test.columns

# %%
# tamplate to adapt
def create_prompt(context, question, answer):
  if len(answer) < 1:
    answer = "Cannot Find Answer"

  prompt_template = f"### CONTEXT\n{context}\n\n### QUESTION\n{question}\n\n### ANSWER\n{answer}</s>"
  return prompt_template

mapped_qa_train = dataset.map(lambda sample: tokenizer(create_prompt(sample['context'], sample['question'], sample['answer'])),
                              )
# Out:
# Map:   0%|          | 0/78577 [00:00<?, ? examples/s]

# %%
mapped_qa_train

# %% [markdown]
# # Train

# %%
from transformers import Trainer,TrainingArguments,DataCollatorForLanguageModeling


trainer = Trainer(
    model = peft_model,
    train_dataset= mapped_qa_train["train"],

    args= TrainingArguments(
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    warmup_steps=100,
    max_steps=100,
    learning_rate=1e-3,
    fp16=True,
    logging_steps=1,
    output_dir='outputs',
    ),
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer.train()
# Out:
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 01:47, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.486800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.431900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.573200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.346400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.401600</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.270800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.398400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.096500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.028700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.111100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.895800</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.697300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.545900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.528700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.166800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.157100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.056700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.873100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.761700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.749100</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.703800</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.649100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.727600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.533100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.461700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.661600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.525000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.642500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.337100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.325200</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.447500</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.551500</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.436600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.514400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.490700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.334200</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.364100</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.285500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.373300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.343000</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.308800</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.455800</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.300500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.343400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.407100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.360300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.230000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.264200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.324000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.255600</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.406200</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.171400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.296100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.397500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.300600</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.199500</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.276200</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.068400</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.217600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.153000</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.427300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.264200</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.231000</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.315400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.272300</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.332600</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.208900</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.274700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.405200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.320000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.134600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.283900</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.159600</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.216200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.271600</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.153700</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.214800</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.170200</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.150200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.255600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.350200</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.248100</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.344300</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.212900</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.175500</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.118000</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.197800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.088300</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.135600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.076900</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.093600</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.132300</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.257400</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.344300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.234300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.234000</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.199700</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.192700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.136300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.231700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=1.600878701210022, metrics={'train_runtime': 108.7496, 'train_samples_per_second': 14.713, 'train_steps_per_second': 0.92, 'total_flos': 550666206904320.0, 'train_loss': 1.600878701210022, 'epoch': 0.02})

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # Push To HF

# %%
HUGGING_FACE_USER_NAME = "ahmedelsayed"
dataset = "sql-create-context"
model = 'bloom-1b1'
peft_model.push_to_hub(f"{HUGGING_FACE_USER_NAME}/{model}", use_auth_token=True)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/16.5M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ahmedelsayed/bloom-1b1/commit/f3d6a628665a4e0959228ebb51c7d1f3943abb5e', commit_message='Upload model', commit_description='', oid='f3d6a628665a4e0959228ebb51c7d1f3943abb5e', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Load From HF Repo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

peft_model_id = f"{HUGGING_FACE_USER_NAME}/{model}"
config = PeftConfig.from_pretrained(peft_model_id)
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, return_dict=True, load_in_8bit=False, device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
qa_model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# adapter_config.json:   0%|          | 0.00/632 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/16.5M [00:00<?, ?B/s]

# %%
from IPython.display import display, Markdown

def make_inference(context, question):
  batch = tokenizer(f"### CONTEXT\n{context}\n\n### QUESTION\n{question}\n\n### ANSWER\n", return_tensors='pt')

  with torch.cuda.amp.autocast():
    output_tokens = qa_model.generate(**batch, max_new_tokens=200)

  display(Markdown((tokenizer.decode(output_tokens[0], skip_special_tokens=True))))

# %%
Test
# Out:
#                                                 question  \
# 0                   What is Home Team, when Tie No is 4?
# 1      What stadium was the game held in when the fin...
# 2           What was the score when she was a runner-up?
# 3      What district featured an election between  ja...
# 4      Show the names of phones and the districts of ...
# ...                                                  ...
# 15710  What is the highest value for Byes, when Wins ...
# 15711                                  error (see notes)
# 15712                  Which Percentage has a Draw of 6?
# 15713  What is the Result of Week larger than 3 on 19...
# 15714  What is the frequency for the country station ...
#
#                                                   answer  \
# 0      SELECT home_team FROM table_name_49 WHERE tie_...
# 1      SELECT stadium FROM table_name_88 WHERE final_...
# 2      SELECT score FROM table_name_38 WHERE outcome ...
# 3      SELECT district FROM table_1341884_40 WHERE ca...
# 4      SELECT T3.Name, T2.District FROM phone_market ...
# ...                                                  ...
# 15710  SELECT MAX(byes) FROM table_name_64 WHERE wins...
# 15711  SELECT MIN(weeks_at_number_1) FROM table_25760...
# 15712  SELECT percentage FROM table_name_9 WHERE draw...
# 15713  SELECT result FROM table_name_94 WHERE week > ...
# 15714  SELECT frequency FROM table_name_65 WHERE form...
#
#                                                  context
# 0      CREATE TABLE table_name_49 (home_team VARCHAR,...
# 1      CREATE TABLE table_name_88 (stadium VARCHAR, f...
# 2      CREATE TABLE table_name_38 (score VARCHAR, out...
# 3      CREATE TABLE table_1341884_40 (district VARCHA...
# 4      CREATE TABLE market (District VARCHAR, Market_...
# ...                                                  ...
# 15710  CREATE TABLE table_name_64 (byes INTEGER, agai...
# 15711  CREATE TABLE table_25760427_2 (weeks_at_number...
# 15712  CREATE TABLE table_name_9 (percentage VARCHAR,...
# 15713  CREATE TABLE table_name_94 (result VARCHAR, we...
# 15714  CREATE TABLE table_name_65 (frequency VARCHAR,...
#
# [15715 rows x 3 columns]

# %%
Test.iloc[0]['context']
# Out:
# 'CREATE TABLE table_name_49 (home_team VARCHAR, tie_no VARCHAR)'

# %%
context = Test.iloc[0]['context']
question = Test.iloc[0]['question']

make_inference(context, question)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1482: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# ### CONTEXT
# CREATE TABLE table_name_49 (home_team VARCHAR, tie_no VARCHAR)
#
# ### QUESTION
# What is Home Team, when Tie No is 4?
#
# ### ANSWER
# SELECT home_team FROM table_name_49 WHERE tie_no = 4

# %%
Test.iloc[0]['answer']
# Out:
# 'SELECT home_team FROM table_name_49 WHERE tie_no = "4"'
